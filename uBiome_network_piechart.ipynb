# %% [markdown]
# **Date: 20-Sep-2016**

# %%
import numpy as np
genus = open('../data/DATA_genus_network_cut_pval_binary_adjacency_NEW.txt', 'rU').read()
genusarr = np.array([i.split('\t') for i in genus.split('\n')[:-1]])

# %%
import matplotlib
# %matplotlib inline
# %load_ext rpy2.ipython
import matplotlib.pyplot as plt
from pylab import *
from scipy import *
import pylab as P
# Out:
# User @ Host | Kernel - Home Folder:
#    DValenzano @ bioinf-blc-05 | Linux - /beegfs/group_dv/home/DValenzano
# Repositories (ID):
#    http://cran.r-project.org (CRAN)
#    http://ftp5.gwdg.de/pub/misc/cran (GWDG)
#    http://cran.rstudio.com/ (RSTUDIO)
# Libraries (Packages):
#    /beegfs/group_dv/home/DValenzano/.local/lib/R/3.2 (1)
#    /beegfs/group_dv/home/DValenzano/.R/3.2.4 (0)
#    /beegfs/common/software/R/3.2.4/lib64/R/library (30)
#    /software/R/3.2.4/lib64/R/library (30)
# /beegfs/group_dv/home/DValenzano/.Python/2.7.11/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:185: RRuntimeWarning: Error in dyn.load(file, DLLpath = DLLpath, ...) :
#   unable to load shared object '/beegfs/common/software/R/3.2.4/lib64/R/library/stats/libs/stats.so':
#   libRlapack.so: cannot open shared object file: No such file or directory
#
#   warnings.warn(x, RRuntimeWarning)
# ...

# %%
wk6_g = [i for i in genusarr[1:] if i[1] == 'YI']
wk16_g = [i for i in genusarr[1:] if i[1] == 'WT']
ymt_g = [i for i in genusarr[1:] if i[1] == 'YM']
abx_g = [i for i in genusarr[1:] if i[1] == 'ABX']
smt_g = [i for i in genusarr[1:] if i[1] == 'SM']

# %%
plt.figure(figsize=(8,1))

plt.subplot(1,2,1)

n, bins, patches = plt.hist([int(i[0]) for i in wk6_g], 10, normed=1, facecolor='r', alpha=0.75, histtype='stepfilled') 
plt.title('wk6_deg')
plt.subplots_adjust(top=1.5, hspace=0.8, wspace=0.5)
#plt.axvline(np.percentile(np.array([int(i[0]) for i in wk6_g]), 90), color='k', linestyle='--', lw=2)
plt.axvline(np.percentile(np.array([int(i[0]) for i in wk6_g]), 95), color='k', linestyle='--', lw=2)
plt.xlim(0,30)
plt.ylim(0,0.6)

plt.subplot(1,2,2)
plt.subplots_adjust(top=1.5, hspace=0.8, wspace=0.5)
plt.axvline(np.percentile(np.array([float(i[2]) for i in wk6_g]), 95), color='k', linestyle='--', lw=2)
n, bins, patches = plt.hist([round(float(i[2]), 2) for i in wk6_g], 10, normed=1, facecolor='r', alpha=0.75, histtype='stepfilled') 
plt.title('wk6_norm_deg')
plt.xlim(0,0.3)
plt.ylim(0,50)
# Out:
# (0, 50)

# %%
plt.figure(figsize=(8,1))

plt.subplot(1,2,1)
n, bins, patches = plt.hist([int(i[0]) for i in ymt_g], 10, normed=1, facecolor='g', alpha=0.75, histtype='stepfilled') 
plt.title('ymt')
plt.subplots_adjust(top=1.5, hspace=0.8, wspace=0.5)
plt.axvline(np.percentile(np.array([int(i[0]) for i in ymt_g]), 95), color='k', linestyle='--', lw=2)
plt.xlim(0,30)
plt.ylim(0,0.6)

plt.subplot(1,2,2)
n, bins, patches = plt.hist([round(float(i[2]), 2) for i in ymt_g], 10, normed=1, facecolor='g', alpha=0.75, histtype='stepfilled') 
plt.title('ymt_norm_deg')
plt.subplots_adjust(top=1.5, hspace=0.8, wspace=0.5)
plt.axvline(np.percentile(np.array([float(i[2]) for i in ymt_g]), 95), color='k', linestyle='--', lw=2)
plt.xlim(0,0.3)
plt.ylim(0,50)
# Out:
# (0, 50)

# %%
plt.figure(figsize=(8,1))

plt.subplot(1,2,1)
n, bins, patches = plt.hist([int(i[0]) for i in wk16_g], 10, normed=1, facecolor='b', alpha=0.75, histtype='stepfilled') 
plt.title('wk16')
plt.subplots_adjust(top=1.5, hspace=0.8, wspace=0.5)
plt.axvline(np.percentile(np.array([int(i[0]) for i in wk16_g]), 95), color='k', linestyle='--', lw=2)
plt.xlim(0,30)
plt.ylim(0,0.6)

plt.subplot(1,2,2)
n, bins, patches = plt.hist([round(float(i[2]), 2) for i in wk16_g], 10, normed=1, facecolor='b', alpha=0.75, histtype='stepfilled') 
plt.title('wk16_norm_deg')
plt.subplots_adjust(top=1.5, hspace=0.8, wspace=0.5)
plt.axvline(np.percentile(np.array([float(i[2]) for i in wk16_g]), 95), color='k', linestyle='--', lw=2)
plt.xlim(0,0.3)
plt.ylim(0,50)
# Out:
# (0, 50)

# %%
plt.figure(figsize=(8,1))

plt.subplot(1,2,1)
n, bins, patches = plt.hist([int(i[0]) for i in abx_g], 10, normed=1, facecolor='y', alpha=0.75, histtype='stepfilled') 
plt.title('abx')
plt.subplots_adjust(top=1.5, hspace=0.8, wspace=0.5)
plt.axvline(np.percentile(np.array([int(i[0]) for i in wk16_g]), 95), color='k', linestyle='--', lw=2)
plt.xlim(0,30)
plt.ylim(0,0.6)

plt.subplot(1,2,2)
n, bins, patches = plt.hist([round(float(i[2]), 2) for i in abx_g], 10, normed=1, facecolor='y', alpha=0.75, histtype='stepfilled') 
plt.title('abx_norm_deg')
plt.subplots_adjust(top=1.5, hspace=0.8, wspace=0.5)
plt.axvline(np.percentile(np.array([float(i[2]) for i in abx_g]), 95), color='k', linestyle='--', lw=2)
plt.xlim(0,0.3)
plt.ylim(0,50)
# Out:
# (0, 50)

# %%
plt.figure(figsize=(8,1))

plt.subplot(1,2,1)
n, bins, patches = plt.hist([int(i[0]) for i in smt_g], 10, normed=1, facecolor='c', alpha=0.75, histtype='stepfilled') 
plt.title('smt')
plt.subplots_adjust(top=1.5, hspace=0.8, wspace=0.5)
plt.axvline(np.percentile(np.array([int(i[0]) for i in smt_g]), 95), color='k', linestyle='--', lw=2)
plt.xlim(0,30)
plt.ylim(0,0.6)

plt.subplot(1,2,2)
n, bins, patches = plt.hist([round(float(i[2]), 2) for i in smt_g], 10, normed=1, facecolor='c', alpha=0.75, histtype='stepfilled') 
plt.title('smt_norm_deg')
plt.subplots_adjust(top=1.5, hspace=0.8, wspace=0.5)
plt.axvline(np.percentile(np.array([float(i[2]) for i in smt_g]), 95), color='k', linestyle='--', lw=2)
plt.xlim(0,0.3)
plt.ylim(0,50)
# Out:
# (0, 50)

# %%
bins = sorted([int(i[0]) for i in wk6_g]) + [np.inf]

plt.figure(figsize=(15,4))

plt.subplot(1,2,2)

plt.xlim(1,26)
n, bins, patches = plt.hist([int(i[0]) for i in wk6_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='wk6', color='r') 
n, bins, patches = plt.hist([int(i[0]) for i in ymt_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='ymt', color='g') 
n, bins, patches = plt.hist([int(i[0]) for i in wk16_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='wk16', color='b') 
n, bins, patches = plt.hist([int(i[0]) for i in abx_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='abx', color='y') 
n, bins, patches = plt.hist([int(i[0]) for i in smt_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='smt', color='c') 
plt.title('cumulative hist (-1)')
# pylab.plot(x, y1, '-b', label='sine')
# pylab.plot(x, y2, '-r', label='cosine')
P.legend(loc='upper right')

P.grid(True)

plt.subplot(1,2,1)
plt.xlim(1,26)
n, bins, patches = plt.hist([int(i[0]) for i in wk6_g], normed=False, bins=bins, histtype='step', cumulative=True, label='wk6', color='r') 
n, bins, patches = plt.hist([int(i[0]) for i in ymt_g], normed=False, bins=bins, histtype='step', cumulative=True, label='ymt', color='g') 
n, bins, patches = plt.hist([int(i[0]) for i in wk16_g], normed=False, bins=bins, histtype='step', cumulative=True, label='wk16', color='b') 
n, bins, patches = plt.hist([int(i[0]) for i in abx_g], normed=False, bins=bins, histtype='step', cumulative=True, label='abx', color='y') 
n, bins, patches = plt.hist([int(i[0]) for i in smt_g], normed=False, bins=bins, histtype='step', cumulative=True, label='smt', color='c') 
plt.title('cumulative hist')
P.legend(loc='upper left')

P.grid(True)

# %%
bins = sorted([float(i[2]) for i in wk6_g]) + [np.inf]

plt.figure(figsize=(15,4))

plt.subplot(1,2,2)
plt.xlim(0.009,0.25)
plt.ylim(0,150)
n, bins, patches = plt.hist([float(i[2]) for i in wk6_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='wk6', color='r') 
n, bins, patches = plt.hist([float(i[2]) for i in ymt_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='ymt', color='g') 
n, bins, patches = plt.hist([float(i[2]) for i in wk16_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='wk16', color='b') 
n, bins, patches = plt.hist([float(i[2]) for i in abx_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='abx', color='y') 
n, bins, patches = plt.hist([float(i[2]) for i in smt_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='smt', color='c') 
plt.title('cumulative hist (-1)')
# pylab.plot(x, y1, '-b', label='sine')
# pylab.plot(x, y2, '-r', label='cosine')
P.legend(loc='upper right')

P.grid(True)

plt.subplot(1,2,1)
plt.xlim(0,0.24)
plt.ylim(0,150)
n, bins, patches = plt.hist([float(i[2]) for i in wk6_g], normed=False, bins=bins, histtype='step', cumulative=True, label='wk6', color='r') 
n, bins, patches = plt.hist([float(i[2]) for i in ymt_g], normed=False, bins=bins, histtype='step', cumulative=True, label='ymt', color='g') 
n, bins, patches = plt.hist([float(i[2]) for i in wk16_g], normed=False, bins=bins, histtype='step', cumulative=True, label='wk16', color='b') 
n, bins, patches = plt.hist([float(i[2]) for i in abx_g], normed=False, bins=bins, histtype='step', cumulative=True, label='abx', color='y') 
n, bins, patches = plt.hist([float(i[2]) for i in smt_g], normed=False, bins=bins, histtype='step', cumulative=True, label='smt', color='c') 
plt.title('cumulative hist')
P.legend(loc='upper left')

P.grid(True)
savefig('cum_hist_norm_NEW.pdf')

# %%
bins = sorted([float(i[2]) for i in wk6_g]) + [np.inf]

plt.figure(figsize=(7.5,4))

#plt.subplot(1,2,2)
plt.xlim(0.009,0.25)
plt.ylim(0,150)
n, bins, patches = plt.hist([float(i[2]) for i in wk6_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='wk6', color='k', lw=2) 
plt.axvline(np.percentile(np.array([float(i[2]) for i in wk6_g]), 95), color='k', linestyle='--', lw=2)
n, bins, patches = plt.hist([float(i[2]) for i in ymt_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='ymt', color='g', lw=2) 
plt.axvline(np.percentile(np.array([float(i[2]) for i in ymt_g]), 95), color='g', linestyle='--', lw=2)
n, bins, patches = plt.hist([float(i[2]) for i in wk16_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='wk16', color='k', lw=2) 
plt.axvline(np.percentile(np.array([float(i[2]) for i in wk16_g]), 95), color='k', linestyle='--', lw=2)
n, bins, patches = plt.hist([float(i[2]) for i in abx_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='abx', color='b', lw=2) 
plt.axvline(np.percentile(np.array([float(i[2]) for i in abx_g]), 95), color='b', linestyle='--', lw=2)
n, bins, patches = plt.hist([float(i[2]) for i in smt_g], normed=False, bins=bins, histtype='step', cumulative=-1, label='smt', color='r', lw=2) 
plt.axvline(np.percentile(np.array([float(i[2]) for i in smt_g]), 95), color='r', linestyle='--', lw=2)
plt.title('cumulative hist (-1)')
# pylab.plot(x, y1, '-b', label='sine')
# pylab.plot(x, y2, '-r', label='cosine')
P.legend(loc='upper right')

P.grid(False)
savefig('cum_hist_rev_90thperc.pdf')

# %% [markdown]
# The Above figure shows the 90th percentile for each cumulative distribution curve
